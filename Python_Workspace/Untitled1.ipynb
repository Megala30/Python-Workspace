# %%
n = 10.5

if type(n) == int:
    print ( " No. is integer" )
else:
    print ( "No. is float" )
# Out:
# No. is float

# %%
N = [10, 42, 5, 87, 23]
largest_number = max(N)

print(largest_number)
# Out:
# 87

# %%
M = [1,2,3,4,5,6,7,8]
count = len(M)

print(count)
# Out:
# 8

# %%
n = [1,2,3,4,5]

Reversed_list = n[:: -1 ] 
print (Reversed_list)
# Out:
# [5, 4, 3, 2, 1]

# %%
a=5
b=10

sum = a + b
print (sum)
# Out:
# 15

# %%
del sum

# %%
a = [10, 20, 30, 40, 50]
total = sum(a)

print(total)
# Out:
# 150

# %%
a = [5,6,7,8,9,10]

avg = sum(a) / len(a) 
print (avg)
# Out:
# 7.5

# %%
L = [24,"Leonard",30,"Meki",24]
for i in L: 
 if type(i) == str:
    print(i)
# Out:
# Leonard
# Meki
